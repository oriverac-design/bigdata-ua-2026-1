# %%
# ============================================================
# INSTALACIÓN (en Google Colab: ejecutar con !)
# ============================================================
# !pip install pymongo dnspython -q

from pymongo import MongoClient
import json

# REEMPLAZA con tu connection string de Atlas:
# Atlas → Connect → Drivers → Python → copia el string
CONNECTION_STRING = "mongodb+srv://wnorabuena_db_user:m1EdPmkPt6MzdFHW@cluster0.ityglap.mongodb.net/?appName=Cluster0"

client = MongoClient(CONNECTION_STRING)
db = client["yape_db"]
comerciantes = db["comerciantes"]
print("✅ Conectado a MongoDB Atlas")
print(f"   DB: {db.name} | Colección: {comerciantes.name}")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 19.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 19.3 MB/s eta 0:00:00
# ✅ Conectado a MongoDB Atlas
#    DB: yape_db | Colección: comerciantes

# %%
# !pip install pymongo[srv]
# Out:
# Requirement already satisfied: pymongo[srv] in /usr/local/lib/python3.12/dist-packages (4.17.0)
# WARNING: pymongo 4.17.0 does not provide the extra 'srv'
# Requirement already satisfied: dnspython<3.0.0,>=2.6.1 in /usr/local/lib/python3.12/dist-packages (from pymongo[srv]) (2.8.0)

# %%
from pymongo import MongoClient

# 1. Coloca tu URI de MongoDB Atlas aquí
URI = "mongodb+srv://wnorabuena_db_user:m1EdPmkPt6MzdFHW@cluster0.ityglap.mongodb.net/?appName=Cluster0"

# 2. Conectar al cliente
cliente = MongoClient(URI)

# 3. Seleccionar la base de datos (puedes cambiar "yape_db" por el nombre de tu BD)
db = cliente["yape_db"]

# 4. Definir la colección "comerciantes" que usa tu script
comerciantes = db["comerciantes"]

print("¡Conexión establecida y colección lista!")
# Out:
# ¡Conexión establecida y colección lista!

# %%
# !pip install certifi
# Out:
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (2026.5.20)

# %%
import certifi
from pymongo import MongoClient

# Tu URI normal
URI = "mongodb+srv://wnorabuena_db_user:m1EdPmkPt6MzdFHW@cluster0.ityglap.mongodb.net/?appName=Cluster0"

# Le decimos al cliente que use los certificados de certifi
cliente = MongoClient(URI, tlsCAFile=certifi.where())

# Seleccionamos BD y colección
db = cliente["yape_db"]
comerciantes = db["comerciantes"]

print("¡Conexión establecida con certificados SSL!")
# Out:
# ¡Conexión establecida con certificados SSL!

# %%
from pymongo import MongoClient

URI = "mongodb+srv://wnorabuena_db_user:m1EdPmkPt6MzdFHW@cluster0.ityglap.mongodb.net/?appName=Cluster0"

# Agregamos tlsAllowInvalidCertificates=True
cliente = MongoClient(URI, tlsAllowInvalidCertificates=True)

db = cliente["yape_db"]
comerciantes = db["comerciantes"]

print("¡Conexión forzada establecida!")
# Out:
# ¡Conexión forzada establecida!

# %%
lista_comerciantes = [
    {
        "ruc": "10456789012",
        "nombre_comercio": "Bodega La Esquina de Don Mario",
        "tipo": "bodega",
        "propietario": "Mario Quispe Condori",
        "distrito": "San Juan de Lurigancho",
        "departamento": "Lima",
        "calificacion": 4.2,
        "yape_activo": True,
        "monto_mensual_soles": 4500.00,
        "categorias": ["abarrotes", "bebidas", "snacks"],   # Array
        "horario": {"apertura": "06:00", "cierre": "22:00"},# Objeto anidado
        "acepta_delivery": False
        # NO tiene: carta, capacidad_mesas, num_empleados
    },
    {
        "ruc": "20512345678",
        "nombre_comercio": "Cevichería El Muelle SAC",
        "tipo": "restaurante",
        "representante_legal": "Ana Flores Rojas",
        "distrito": "Miraflores",
        "departamento": "Lima",
        "calificacion": 4.8,
        "yape_activo": True,
        "monto_mensual_soles": 28000.00,
        "carta": [                                           # Array de objetos
            {"plato": "Ceviche clásico", "precio": 28.00},
            {"plato": "Leche de tigre",  "precio": 18.00},
            {"plato": "Tiradito",        "precio": 32.00}
        ],
        "capacidad_mesas": 45,
        "num_empleados": 12,
        "horario": {"apertura": "12:00", "cierre": "17:00"},
        "acepta_delivery": True,
        "plataformas_delivery": ["Rappi", "PedidosYa"]
        # NO tiene: categorias, acepta_tarjeta_fisica
    },
    {
        "ruc": "10789012345",
        "nombre_comercio": "Farmacia San Pablo Express",
        "tipo": "farmacia",
        "propietario": "Carlos Mendoza Ríos",
        "distrito": "Los Olivos",
        "departamento": "Lima",
        "calificacion": 4.5,
        "yape_activo": True,
        "monto_mensual_soles": 12000.00,
        "productos_destacados": ["paracetamol", "ibuprofeno", "vitaminas"],
        "horario": {"apertura": "07:00", "cierre": "23:00"},
        "venta_con_receta": True,
        "codigo_digemid": "F-2023-00456",  # Campo único de farmacias
        "acepta_delivery": True
    },
    {
        "ruc": "10234567891",
        "nombre_comercio": "Taxi Express — Luis Tapia",
        "tipo": "taxi",
        "propietario": "Luis Tapia Salcedo",
        "distrito": "Callao",
        "departamento": "Lima",
        "calificacion": 4.0,
        "yape_activo": True,
        "monto_mensual_soles": 3200.00,
        "vehiculo": {                        # Objeto único de taxis
            "placa": "ABC-123",
            "modelo": "Toyota Yaris 2022",
            "capacidad": 4
        },
        "zonas_cobertura": ["Callao", "Bellavista", "La Perla", "Miraflores"],
        "acepta_delivery": False
    },
    {
        "ruc": "20987654321",
        "nombre_comercio": "Distribuidora Norte SAC",
        "tipo": "empresa",
        "representante_legal": "Patricia Luna Torres",
        "distrito": "Independencia",
        "departamento": "Lima",
        "calificacion": 3.9,
        "yape_activo": True,
        "monto_mensual_soles": 85000.00,
        "num_empleados": 45,
        "sectores": ["abarrotes", "limpieza", "bebidas"],
        "clientes_mayoristas": 230,
        "horario": {"apertura": "08:00", "cierre": "18:00"},
        "acepta_delivery": True,
        "zonas_despacho": ["Lima Norte", "Lima Centro"]
    }
]

resultado = comerciantes.insert_many(lista_comerciantes)
print(f"✅ {len(resultado.inserted_ids)} comerciantes insertados en Atlas")
for i, id_ in enumerate(resultado.inserted_ids):
    print(f"   {lista_comerciantes[i]['tipo'].upper()}: {id_}")
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# /tmp/ipykernel_22504/2289633480.py in <cell line: 0>()
#      90 ]
#      91
# ---> 92 resultado = comerciantes.insert_many(lista_comerciantes)
#      93 print(f"✅ {len(resultado.inserted_ids)} comerciantes insertados en Atlas")
#      94 for i, id_ in enumerate(resultado.inserted_ids):
#
# /usr/local/lib/python3.12/dist-packages/pymongo/_csot.py in csot_wrapper(self, *args, **kwargs)
#     123                     with _TimeoutContext(timeout):
#     124                         return func(self, *args, **kwargs)
# --> 125             return func(self, *args, **kwargs)
#     126
#     127     return cast(F, csot_wrapper)
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/collection.py in insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     972         blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
#     973         blk.ops = list(gen())
# --> 974         blk.execute(write_concern, session, _Op.INSERT)
#     975         return InsertManyResult(inserted_ids, write_concern.acknowledged)
#     976
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/bulk.py in execute(self, write_concern, session, operation)
#     749                 return None
#     750         else:
# --> 751             return self.execute_command(generator, write_concern, session, operation)
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/bulk.py in execute_command(self, generator, write_concern, session, operation)
#     602
#     603         client = self.collection.database.client
# --> 604         _ = client._retryable_write(
#     605             self.is_retryable,
#     606             retryable_bulk,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _retryable_write(self, retryable, func, session, operation, bulk, operation_id)
#    2111         """
#    2112         with self._tmp_session(session) as s:
# -> 2113             return self._retry_with_session(retryable, func, s, bulk, operation, operation_id)
#    2114
#    2115     def _cleanup_cursor_no_lock(
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _retry_with_session(self, retryable, func, session, bulk, operation, operation_id)
#    1984             retryable and self.options.retry_writes and session and not session.in_transaction
#    1985         )
# -> 1986         return self._retry_internal(
#    1987             func=func,
#    1988             session=session,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/_csot.py in csot_wrapper(self, *args, **kwargs)
#     123                     with _TimeoutContext(timeout):
#     124                         return func(self, *args, **kwargs)
# --> 125             return func(self, *args, **kwargs)
#     126
#     127     return cast(F, csot_wrapper)
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id, is_run_command, is_aggregate_write)
#    2036             is_run_command=is_run_command,
#    2037             is_aggregate_write=is_aggregate_write,
# -> 2038         ).run()
#    2039
#    2040     def _retryable_read(
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in run(self)
#    2809             self._check_last_error(check_csot=True)
#    2810             try:
# -> 2811                 res = self._read() if self._is_read else self._write()
#    2812                 # Track whether the transaction has completed a command.
#    2813                 # If we need to apply backpressure to the first command,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _write(self)
#    2990             max_wire_version = 0
#    2991             is_mongos = False
# -> 2992             self._server = self._get_server()
#    2993             with self._client._checkout(self._server, self._session) as conn:
#    2994                 max_wire_version = conn.max_wire_version
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _get_server(self)
#    2973         :return: Abstraction to connect to server
#    2974         """
# -> 2975         return self._client._select_server(
#    2976             self._server_selector,
#    2977             self._session,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _select_server(self, server_selector, session, operation, address, deprioritized_servers, operation_id)
#    1849                     raise AutoReconnect("server %s:%s no longer available" % address)  # noqa: UP031
#    1850             else:
# -> 1851                 server = topology.select_server(
#    1852                     server_selector,
#    1853                     operation,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/topology.py in select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     426     ) -> Server:
#     427         """Like select_servers, but choose a random server if several match."""
# --> 428         server = self._select_server(
#     429             selector,
#     430             operation,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/topology.py in _select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     400         operation_id: Optional[int] = None,
#     401     ) -> Server:
# --> 402         servers = self.select_servers(
#     403             selector,
#     404             operation,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/topology.py in select_servers(self, selector, operation, server_selection_timeout, address, operation_id, deprioritized_servers)
#     296
#     297         with self._lock:
# --> 298             server_descriptions = self._select_servers_loop(
#     299                 selector,
#     300                 server_timeout,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/topology.py in _select_servers_loop(self, selector, timeout, operation, operation_id, address, deprioritized_servers)
#     357                         failure=self._error_message(selector),
#     358                     )
# --> 359                 raise ServerSelectionTimeoutError(
#     360                     f"{self._error_message(selector)}, Timeout: {timeout}s, Topology Description: {self.description!r}"
#     361                 )
#
# ServerSelectionTimeoutError: SSL handshake failed: ac-lqfsux7-shard-00-01.ityglap.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1010) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),SSL handshake failed: ac-lqfsux7-shard-00-00.ityglap.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1010) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),SSL handshake failed: ac-lqfsux7-shard-00-02.ityglap.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1010) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 6a405a7165664ae944c2a562, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('ac-lqfsux7-shard-00-00.ityglap.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('SSL handshake failed: ac-lqfsux7-shard-00-00.ityglap.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1010) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>, <ServerDescription ('ac-lqfsux7-shard-00-01.ityglap.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('SSL handshake failed: ac-lqfsux7-shard-00-01.ityglap.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1010) (configured ti...

# %%
print("="*55)
print("CONSULTA 1: Comerciantes premium (calificación > 4.3 y activos)")
premium = list(comerciantes.find(
    {"calificacion": {"$gt": 4.3}, "yape_activo": True},
    {"nombre_comercio": 1, "tipo": 1, "calificacion": 1, "_id": 0}
).sort("calificacion", -1))
for c in premium:
    print(f"  ★ {c['nombre_comercio']} ({c['tipo']}) — {c['calificacion']}")

print()
print("CONSULTA 2: Comercios con delivery en Lima que facturan > S/10,000/mes")
alto_valor = list(comerciantes.find(
    {
        "acepta_delivery": True,
        "departamento": "Lima",
        "monto_mensual_soles": {"$gt": 10000}
    },
    {"nombre_comercio": 1, "monto_mensual_soles": 1, "distrito": 1, "_id": 0}
))
for c in alto_valor:
    print(f"  → {c['nombre_comercio']} ({c['distrito']}): S/{c['monto_mensual_soles']:,.0f}/mes")

print()
print("CONSULTA 3: Bodegas O farmacias (operador $in)")
bodegas_farmacias = list(comerciantes.find(
    {"tipo": {"$in": ["bodega", "farmacia"]}},
    {"nombre_comercio": 1, "tipo": 1, "_id": 0}
))
for c in bodegas_farmacias:
    print(f"  → [{c['tipo']}] {c['nombre_comercio']}")
# Out:
# =======================================================
# CONSULTA 1: Comerciantes premium (calificación > 4.3 y activos)
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# /tmp/ipykernel_22504/2273431386.py in <cell line: 0>()
#       1 print("="*55)
#       2 print("CONSULTA 1: Comerciantes premium (calificación > 4.3 y activos)")
# ----> 3 premium = list(comerciantes.find(
#       4     {"calificacion": {"$gt": 4.3}, "yape_activo": True},
#       5     {"nombre_comercio": 1, "tipo": 1, "calificacion": 1, "_id": 0}
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/cursor.py in __next__(self)
#    1164
#    1165     def __next__(self) -> _DocumentType:
# -> 1166         return self.next()
#    1167
#    1168     def __iter__(self) -> Cursor[_DocumentType]:
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/cursor.py in next(self)
#    1140         if self._empty:
#    1141             raise StopIteration
# -> 1142         if len(self._data) or self._refresh():
#    1143             return self._data.popleft()
#    1144         else:
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/cursor.py in _refresh(self)
#    1088                 self._exhaust,
#    1089             )
# -> 1090             self._send_message(q)
#    1091         elif self._id:  # Get More
#    1092             if self._limit:
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/cursor.py in _send_message(self, operation)
#     983
#     984         try:
# --> 985             response = client._run_operation(
#     986                 operation, self._unpack_response, address=self._address
#     987             )
#
# /usr/local/lib/python3.12/dist-packages/pymongo/_csot.py in csot_wrapper(self, *args, **kwargs)
#     123                     with _TimeoutContext(timeout):
#     124                         return func(self, *args, **kwargs)
# --> 125             return func(self, *args, **kwargs)
#     126
#     127     return cast(F, csot_wrapper)
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _run_operation(self, operation, unpack_res, address)
#    1954             )
#    1955
# -> 1956         return self._retryable_read(
#    1957             _cmd,
#    1958             operation.read_preference,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id, is_run_command, is_aggregate_write)
#    2074         )
#    2075         with self._tmp_session(session) as s:
# -> 2076             return self._retry_internal(
#    2077                 func,
#    2078                 s,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/_csot.py in csot_wrapper(self, *args, **kwargs)
#     123                     with _TimeoutContext(timeout):
#     124                         return func(self, *args, **kwargs)
# --> 125             return func(self, *args, **kwargs)
#     126
#     127     return cast(F, csot_wrapper)
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id, is_run_command, is_aggregate_write)
#    2036             is_run_command=is_run_command,
#    2037             is_aggregate_write=is_aggregate_write,
# -> 2038         ).run()
#    2039
#    2040     def _retryable_read(
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in run(self)
#    2809             self._check_last_error(check_csot=True)
#    2810             try:
# -> 2811                 res = self._read() if self._is_read else self._write()
#    2812                 # Track whether the transaction has completed a command.
#    2813                 # If we need to apply backpressure to the first command,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _read(self)
#    3025         :return: Output for func()'s call
#    3026         """
# -> 3027         self._server = self._get_server()
#    3028         assert self._read_pref is not None, "Read Preference required on read calls"
#    3029         with self._client._conn_from_server(self._read_pref, self._server, self._session) as (
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _get_server(self)
#    2973         :return: Abstraction to connect to server
#    2974         """
# -> 2975         return self._client._select_server(
#    2976             self._server_selector,
#    2977             self._session,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _select_server(self, server_selector, session, operation, address, deprioritized_servers, operation_id)
#    1849                     raise AutoReconnect("server %s:%s no longer available" % address)  # noqa: UP031
#    1850             else:
# -> 1851                 server = topology.select_server(
#    1852                     server_selector,
#    1853                     operation,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/topology.py in select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     426     ) -> Server:
#     427         """Like select_servers, but choose a random server if several match."""
# --> 428         server = self._select_server(
#     429             selector,
#     430             operation,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/topology.py in _select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     400         operation_id: Optional[int] = None,
#     401     ) -> Server:
# --> 402         servers = self.select_servers(
#     403             selector,
#     404             operation,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/topology.py in select_servers(self, selector, operation, server_selection_timeout, address, operation_id, deprioritized_servers)
#     296
#     297         with self._lock:
# --> 298             server_descriptions = self._select_servers_loop(
#     299                 selector,
#     300                 server_timeout,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/topology.py in _select_servers_loop(self, selector, timeout, operation, operation_id, address, deprioritized_servers)
#     357                         failure=self._error_message(selector),
#     358                     )
# --> 359                 raise ServerSelectionTimeoutError(
#     360                     f"{self._error_message(selector)}, Timeout: {timeout}s, Topology Description: {self.description!r}"
#     361                 )
#
# ServerSelectionTimeoutError: SSL handshake failed: ac-lqfsux7-shard-00-01.ityglap.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1010) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),SSL handshake failed: ac-lqfsux7-shard-00-00.ityglap.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1010) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),SSL handshake failed: ac-lqfsux7-shard-00-02.ityglap.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1010) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 6a405a7165664ae944c2a562, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('ac-lqfsux7-shard-00-00.ityglap.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('SSL handshake failed: ac-lqfsux7-shard-00-00.ityglap.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1010) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>, <ServerDescription ('ac-lqfsux7-shard-00-01.ityglap.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('SSL handshake failed: ac-lqfsux7-shard-00-01.ityglap.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1010) (configured ti...

# %%
pipeline_reporte = [
    # Paso 1: Solo comerciantes activos en Lima
    {"$match": {"yape_activo": True, "departamento": "Lima"}},

    # Paso 2: Agrupar por tipo de comercio
    {"$group": {
        "_id": "$tipo",
        "total_comercios":     {"$sum": 1},
        "facturacion_total":   {"$sum": "$monto_mensual_soles"},
        "calificacion_prom":   {"$avg": "$calificacion"},
        "con_delivery":        {"$sum": {"$cond": ["$acepta_delivery", 1, 0]}}
    }},

    # Paso 3: Ordenar por facturación total descendente
    {"$sort": {"facturacion_total": -1}},

    # Paso 4: Formatear la salida
    {"$project": {
        "tipo_comercio":    "$_id",
        "total_comercios":  1,
        "facturacion_total": 1,
        "calificacion_prom": {"$round": ["$calificacion_prom", 1]},
        "con_delivery":     1,
        "_id": 0
    }}
]

print(" REPORTE COMERCIAL YAPE — FACTURACIÓN POR TIPO:")
print(f"{'TIPO':<20} {'COMERCIOS':>9} {'FACTURACIÓN/MES':>16} {'RATING':>7} {'C/DELIVERY':>11}")
print("-" * 67)
for r in comerciantes.aggregate(pipeline_reporte):
    print(f"{r['tipo_comercio']:<20} {r['total_comercios']:>9} "
          f"S/{r['facturacion_total']:>13,.0f} {r['calificacion_prom']:>7} "
          f"{r['con_delivery']:>11}")
# Out:
#  REPORTE COMERCIAL YAPE — FACTURACIÓN POR TIPO:
# TIPO                 COMERCIOS  FACTURACIÓN/MES  RATING  C/DELIVERY
# -------------------------------------------------------------------
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# /tmp/ipykernel_22504/356154392.py in <cell line: 0>()
#      29 print(f"{'TIPO':<20} {'COMERCIOS':>9} {'FACTURACIÓN/MES':>16} {'RATING':>7} {'C/DELIVERY':>11}")
#      30 print("-" * 67)
# ---> 31 for r in comerciantes.aggregate(pipeline_reporte):
#      32     print(f"{r['tipo_comercio']:<20} {r['total_comercios']:>9} "
#      33           f"S/{r['facturacion_total']:>13,.0f} {r['calificacion_prom']:>7} "
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/collection.py in aggregate(self, pipeline, session, let, comment, **kwargs)
#    3036         """
#    3037         with self._database.client._tmp_session(session) as s:
# -> 3038             return self._aggregate(
#    3039                 _CollectionAggregationCommand,
#    3040                 pipeline,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/_csot.py in csot_wrapper(self, *args, **kwargs)
#     123                     with _TimeoutContext(timeout):
#     124                         return func(self, *args, **kwargs)
# --> 125             return func(self, *args, **kwargs)
#     126
#     127     return cast(F, csot_wrapper)
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/collection.py in _aggregate(self, aggregation_command, pipeline, cursor_class, session, let, comment, **kwargs)
#    2933         )
#    2934
# -> 2935         return self._database.client._retryable_read(
#    2936             cmd.get_cursor,
#    2937             cmd.get_read_preference(session),  # type: ignore[arg-type]
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id, is_run_command, is_aggregate_write)
#    2074         )
#    2075         with self._tmp_session(session) as s:
# -> 2076             return self._retry_internal(
#    2077                 func,
#    2078                 s,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/_csot.py in csot_wrapper(self, *args, **kwargs)
#     123                     with _TimeoutContext(timeout):
#     124                         return func(self, *args, **kwargs)
# --> 125             return func(self, *args, **kwargs)
#     126
#     127     return cast(F, csot_wrapper)
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id, is_run_command, is_aggregate_write)
#    2036             is_run_command=is_run_command,
#    2037             is_aggregate_write=is_aggregate_write,
# -> 2038         ).run()
#    2039
#    2040     def _retryable_read(
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in run(self)
#    2809             self._check_last_error(check_csot=True)
#    2810             try:
# -> 2811                 res = self._read() if self._is_read else self._write()
#    2812                 # Track whether the transaction has completed a command.
#    2813                 # If we need to apply backpressure to the first command,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _read(self)
#    3025         :return: Output for func()'s call
#    3026         """
# -> 3027         self._server = self._get_server()
#    3028         assert self._read_pref is not None, "Read Preference required on read calls"
#    3029         with self._client._conn_from_server(self._read_pref, self._server, self._session) as (
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _get_server(self)
#    2973         :return: Abstraction to connect to server
#    2974         """
# -> 2975         return self._client._select_server(
#    2976             self._server_selector,
#    2977             self._session,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/mongo_client.py in _select_server(self, server_selector, session, operation, address, deprioritized_servers, operation_id)
#    1849                     raise AutoReconnect("server %s:%s no longer available" % address)  # noqa: UP031
#    1850             else:
# -> 1851                 server = topology.select_server(
#    1852                     server_selector,
#    1853                     operation,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/topology.py in select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     426     ) -> Server:
#     427         """Like select_servers, but choose a random server if several match."""
# --> 428         server = self._select_server(
#     429             selector,
#     430             operation,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/topology.py in _select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     400         operation_id: Optional[int] = None,
#     401     ) -> Server:
# --> 402         servers = self.select_servers(
#     403             selector,
#     404             operation,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/topology.py in select_servers(self, selector, operation, server_selection_timeout, address, operation_id, deprioritized_servers)
#     296
#     297         with self._lock:
# --> 298             server_descriptions = self._select_servers_loop(
#     299                 selector,
#     300                 server_timeout,
#
# /usr/local/lib/python3.12/dist-packages/pymongo/synchronous/topology.py in _select_servers_loop(self, selector, timeout, operation, operation_id, address, deprioritized_servers)
#     357                         failure=self._error_message(selector),
#     358                     )
# --> 359                 raise ServerSelectionTimeoutError(
#     360                     f"{self._error_message(selector)}, Timeout: {timeout}s, Topology Description: {self.description!r}"
#     361                 )
#
# ServerSelectionTimeoutError: SSL handshake failed: ac-lqfsux7-shard-00-01.ityglap.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1010) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),SSL handshake failed: ac-lqfsux7-shard-00-00.ityglap.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1010) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),SSL handshake failed: ac-lqfsux7-shard-00-02.ityglap.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1010) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 6a405a7165664ae944c2a562, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('ac-lqfsux7-shard-00-00.ityglap.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('SSL handshake failed: ac-lqfsux7-shard-00-00.ityglap.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1010) (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>, <ServerDescription ('ac-lqfsux7-shard-00-01.ityglap.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('SSL handshake failed: ac-lqfsux7-shard-00-01.ityglap.mongodb.net:27017: [SSL: TLSV1_ALERT_INTERNAL_ERROR] tlsv1 alert internal error (_ssl.c:1010) (configured ti...
